# %% [markdown]
# 1. Creating variable

# %%
attendance1 <- 0.82
average1 <- 0.78
print(average)
# Out:
# [1] 0.78

# %% [markdown]
# 2.Basic Calculaion

# %%
Quiz <- 85
Labaratory <- 90
Project <-88
Exam <-80

add <- 0.20 * Quiz + 0.25 * Labaratory + 0.25 * Project + 0.30 * Exam
print(add)
# Out:
# [1] 85.5

# %% [markdown]
# 3.Using Comparison operators

# %%
attendance <- 72
grade <- 70



if (attendance < 75){
  print("yes it is less")
}else{
  print("it is 75")
}

if (grade < 75){
  print("yes it is less")
}else{
  print("it is 75")
}
# Out:
# [1] "yes it is less"
# [1] "yes it is less"

# %%
4.Using AND and OR

# %%
if (attendance && grade < 75 ){
  print("both at risk 75")
}

if (attendance || grade < 75){
  print("at least one at risk 75")
}
# Out:
# [1] "both at risk 75"
# [1] "at least one at risk 75"

# %% [markdown]
# 5.Simple IF Statement

# %%
if (grade >= 75){
  print("Grade =>75,PASS")
}else{
  print("Grade <75,FAIL")
}
# Out:
# [1] "Grade <75,FAIL"

# %%
6.Multiple Conditions

# %%
if (grade > 90){
  print("Excellent")
}else if (grade > 85 && grade < 89){
  print("Very Good")
}else if (grade > 80 && grade < 84){
print("Good")
}else if(grade > 75 && grade < 79)
{print("Passed")
} else if (grade < 75)
{
    print("Fail")
  }
# Out:
# [1] "Fail"

# %% [markdown]
# 7.Creating a Function

# %%
classify_grade <- function(grade){
if (grade >= 90){
  print("Excellent")
}else if (grade >= 85 && grade <= 89){
  print("Very Good")
}else if (grade >= 80 && grade <= 84){
print("Good")
}else if(grade >= 75 && grade <= 79)
{print("Passed")
} else if (grade < 75)
{
    print("Fail")
  }}

classify_grade(89)
# Out:
# [1] "Very Good"

# %% [markdown]
# 8.Creating a Data Frame

# %%
students <- data.frame(
  Student_ID
)
# Out:
# Error in c("S001", "S002", "S003", ): argument 4 is empty
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "argument 4 is empty", base::quote(c("S001", "S002", "S003",
#  .     )))
